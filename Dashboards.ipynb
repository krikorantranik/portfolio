# %% [markdown]
# <a href="https://colab.research.google.com/github/krikorantranik/Work/blob/main/Dashboards.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# These are simple examples of Tableau dashboards I was able to put together using data provided by Kaggle.

# %% [markdown]
# This is a quick analysis of the musical characteristics of Top-of-the-Chart songs for the last 20 years. We can see in it that the evolution of music towards more relaxed songs (less loudness), and into more similar sounds (the box and whiskers charts get shorter in for example liveness).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This is a simple dashboard showing the damage caused to airplanes by bird impacts in the Southwest of the United States. The most telling thing of this quick review is that there is a seasonal component in the events reported and that its number is growing along the years.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Tableau dasbhoards allow the use of interactive actions, like by clicking on a point, data about it can be shown, and inmidiately a "highlight filter" is set on its value. In this case I set it to show relevant information about the airport.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Tableau also provides some basic analytics out of the box. In this next example I apply a regression exponential line to the time series, showing its P value and equation. Tableau (Power BI as well) comes with a module to connect to a Python instance, which gives the user the freedom to run Python code and take advantage of its libraries and visualizations.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# On the flip side, Tableau's BI tool is behind that of other technologies, like Power BI. It allows only basic joins which limits BI activities to be performed outside of Tableau. It does allow transformations and aggregations as its own kind of DAX structures to create calculated columns

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example of a calculated field

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This is a quick analysis from a dataset of top 500 companies to work in, according to Forbes, in 2023. In this particular case, I used the filter feature in Power BI to focus on German companies in the area of Construction, Oil and Gas Operations, Mining and Chemicals

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Power BI allows for similar capabilities, but it has some important differences. First, filtering is extremely easy; clicking on one feature in the dashboard will filter for all visuals. Also, for some reason, I find that it can fit more visuals on one page, which is a good thing.
#
# Now, in terms of visuals, I think that the way Tableau handles the art is better.
#
# Where Power BI definitely wins is in business intelligence and analytics. For example, from this same dataset, it is possible to build a summary with just a few clicks. The text can be improved by hand, but consider it was completely generated by AI:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The BI is way more powerful than Power BI (pun intended). The  Power Query Editor and the Model View are, in my opinion, beating Tableau's load tool. Also, I find that the integration with R or Python is easier in Power BI.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The other great tool that Power BI has that unfortunately cannot be displayed here since it requires a business login is the fact that you can import more visuals from the community, which basically allows the use of an infinite number of different options for visualizations.
#
#
# In conclusion, in my opinion, Tableau is easier to use and produces more visually appealing dashboards, but Power BI has better analytics, better data manipulation, and more options for visual cards.
